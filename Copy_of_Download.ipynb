# %% [markdown]
# <a href="https://colab.research.google.com/github/rfox7/jupyter-exploration/blob/main/Copy_of_Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first markdown cell in Jupyter.

# %%
print("Hello, World!")
# Out:
# Hello, World!
